# %%
import numpy as np
import time

# %%
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = np.zeros_like(x)

        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k

        x = x_new

    return x, max_iterations

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = x.copy()

        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i+1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k

        x = x_new

    return x, max_iterations

# %%
A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float)

b = np.array([14, 22, 33, 26, 22], dtype=float)

x0 = np.zeros(len(b))
tol = 1e-6
max_iterations = 10000

start = time.time()
x_jacobi, iter_jacobi = jacobi(A, b, x0, tol, max_iterations)
end = time.time()
time_jacobi = end - start

start = time.time()
x_gs, iter_gs = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.time()
time_gs = end - start

print("Jacobi solution:", x_jacobi)
print("Jacobi iterations:", iter_jacobi)
print("Jacobi time:", time_jacobi)

print("\nGauss-Seidel solution:", x_gs)
print("Gauss-Seidel iterations:", iter_gs)
print("Gauss-Seidel time:", time_gs)
# Out:
# <ipython-input-16-754a0b61f5d4>:9: RuntimeWarning: overflow encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-16-754a0b61f5d4>:9: RuntimeWarning: invalid value encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-17-ed068a8c92c4>:10: RuntimeWarning: overflow encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i+1, n))
# <ipython-input-17-ed068a8c92c4>:10: RuntimeWarning: invalid value encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i+1, n))
# Jacobi solution: [nan nan nan nan nan]
# Jacobi iterations: 10000
# Jacobi time: 0.5088684558868408
#
# Gauss-Seidel solution: [nan nan nan nan nan]
# Gauss-Seidel iterations: 10000
# Gauss-Seidel time: 0.46332478523254395

# %% [markdown]
# # Jacobi and Gauss-Seidel did not converge. The iterations kept growing and produced overflow/NaN warnings. This led me to believe that it diverges

# %%
A = np.array([
    [0.582745, 0.48,     0.10,     0.0,      0.0],
    [0.48,     1.044129, 0.46,     0.10,     0.0],
    [0.10,     0.46,     1.10431,  0.44,     0.10],
    [0.0,      0.10,     0.44,     0.963889, 0.42],
    [0.0,      0.0,      0.10,     0.42,     0.522565]
], dtype=float)

b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

x0 = np.zeros(len(b))
tol = 1e-6
max_iterations = 10000

start = time.time()
x_jacobi, iter_jacobi = jacobi(A, b, x0, tol, max_iterations)
end = time.time()
time_jacobi = end - start

start = time.time()
x_gs, iter_gs = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.time()
time_gs = end - start

print("Jacobi solution:", x_jacobi)
print("Jacobi iterations:", iter_jacobi)
print("Jacobi time:", time_jacobi)

print("\nGauss-Seidel solution:", x_gs)
print("Gauss-Seidel iterations:", iter_gs)
print("Gauss-Seidel time:", time_gs)
# Out:
# Jacobi solution: [1.0000005 1.0000005 1.0000005 1.0000005 1.0000005]
# Jacobi iterations: 3462
# Jacobi time: 0.1818399429321289
#
# Gauss-Seidel solution: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# Gauss-Seidel iterations: 20
# Gauss-Seidel time: 0.0010924339294433594
