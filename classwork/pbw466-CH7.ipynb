# %%
import numpy as np
import time

# %%
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = np.zeros_like(x)

        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k

        x = x_new

    return x, max_iterations

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = x.copy()

        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i+1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k

        x = x_new

    return x, max_iterations

# %% [markdown]
# # Part A

# %%
A = np.array([
    [0.582745, 0.48,     0.10,     0.0,      0.0],
    [0.48,     1.044129, 0.46,     0.10,     0.0],
    [0.10,     0.46,     1.10431,  0.44,     0.10],
    [0.0,      0.10,     0.44,     0.963889, 0.42],
    [0.0,      0.0,      0.10,     0.42,     0.522565]
], dtype=float)

b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)

x0 = np.zeros(len(b))
tol = 1e-6
max_iterations = 10000

start = time.time()
x_jacobi, iter_jacobi = jacobi(A, b, x0, tol, max_iterations)
end = time.time()
time_jacobi = end - start

start = time.time()
x_gs, iter_gs = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.time()
time_gs = end - start

print("Jacobi solution:", x_jacobi)
print("Jacobi iterations:", iter_jacobi)
print("Jacobi time:", time_jacobi)

print("\nGauss-Seidel solution:", x_gs)
print("Gauss-Seidel iterations:", iter_gs)
print("Gauss-Seidel time:", time_gs)
# Out:
# Jacobi solution: [1.0000005 1.0000005 1.0000005 1.0000005 1.0000005]
# Jacobi iterations: 3462
# Jacobi time: 0.14848661422729492
#
# Gauss-Seidel solution: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# Gauss-Seidel iterations: 20
# Gauss-Seidel time: 0.0009634494781494141

# %% [markdown]
# # Part B

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1])
x0 = np.zeros(len(b))
tol = 1e-6
max_iterations = 10000

start = time.time()
x_jacobi, iter_jacobi = jacobi(A, b, x0, tol, max_iterations)
end = time.time()
time_jacobi = end - start

start = time.time()
x_gs, iter_gs = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.time()
time_gs = end - start

print("Jacobi solution:", x_jacobi)
print("Jacobi iterations:", iter_jacobi)
print("Jacobi time:", time_jacobi)

print("\nGauss-Seidel solution:", x_gs)
print("Gauss-Seidel iterations:", iter_gs)
print("Gauss-Seidel time:", time_gs)
# Out:
# Jacobi solution: [0.39345418 0.        ]
# Jacobi iterations: 10000
# Jacobi time: 0.36113977432250977
#
# Gauss-Seidel solution: [1. 0.]
# Gauss-Seidel iterations: 1
# Gauss-Seidel time: 0.00019884109497070312

# %%
A = np.array ([[2,1], [1,1]])
B = np.array([[2,4], [1,2]])
print(np.linalg.det(A))
print(np.linalg.det(B))

Ainv = np.linalg.inv(A)
#Binv = np.linalg.inv(B)
print(Ainv)

print(f"A: {A}")
kappa = np.linalg.cond(A,2)
print(kappa)
# Out:
# 1.0
# 0.0
# [[ 1. -1.]
#  [-1.  2.]]
# A: [[2 1]
#  [1 1]]
# 6.854101966249688

# %% [markdown]
# # Part C

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1.0001])

x0 = np.zeros(len(b))
tol = 1e-6
max_iterations = 10000

start = time.time()
x_jacobi, iter_jacobi = jacobi(A, b, x0, tol, max_iterations)
end = time.time()
time_jacobi = end - start

start = time.time()
x_gs, iter_gs = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.time()
time_gs = end - start

print("Jacobi solution:", x_jacobi)
print("Jacobi iterations:", iter_jacobi)
print("Jacobi time:", time_jacobi)

print("\nGauss-Seidel solution:", x_gs)
print("Gauss-Seidel iterations:", iter_gs)
print("Gauss-Seidel time:", time_gs)
# Out:
# Jacobi solution: [0.         0.39345418]
# Jacobi iterations: 10000
# Jacobi time: 0.307142972946167
#
# Gauss-Seidel solution: [0.36793462 0.63210217]
# Gauss-Seidel iterations: 10000
# Gauss-Seidel time: 0.17856264114379883

# %% [markdown]
# # Diagonally dominant challenge

# %%
def diagDom(A) -> bool:
    for i in range(5):
        for j in range(5):
            ind = ((i)*5 + (j+1))
            sum = 0
            if (i==j):
                diag = abs(A[ind])
            else: 
                sum =+ abs(A[ind])
            if (diag < sum):
                return false
        sum = 0
    return true

# %%
A = np.array([
    [0.582745, 0.48,     0.10,     0.0,      0.0],
    [0.48,     1.044129, 0.46,     0.10,     0.0],
    [0.10,     0.46,     1.10431,  0.44,     0.10],
    [0.0,      0.10,     0.44,     0.963889, 0.42],
    [0.0,      0.0,      0.10,     0.42,     0.522565]
], dtype=float)
dom = diagDom(A)
print(A)
print(f"matrix is diagonally dominant is {dom}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-7d75da7d9981> in <module>
#       6     [0.0,      0.0,      0.10,     0.42,     0.522565]
#       7 ], dtype=float)
# ----> 8 dom = diagDom(A)
#       9 print(A)
#      10 print(f"matrix is diagonally dominant is {dom}")
#
# <ipython-input-14-1e58deab7921> in diagDom(A)
#       8             else:
#       9                 sum =+ abs(A[ind])
# ---> 10             if (diag < sum):
#      11                 return false
#      12         sum = 0
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
