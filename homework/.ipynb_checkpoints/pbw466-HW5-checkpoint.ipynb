# %%
def leastSq(X,Y):
    n = len(X)
    sumX = sum(X)
    sumY = sum(Y)
    sumX2 = sum(X**2)
    sumXY = sum(X*Y)
    m = ((n * sumXY) - (sumX * sumY))/((n * sumX2) - (sumX**2))
    c = (sumY - (m * sumX))/n
    return m,c

# %%
import numpy as np
import random

X = np.random.rand(10)
X = np.sort(X)
Y = np.random.rand(10)
m,c = leastSq(X,Y)
print(m)
print(c)
# Out:
# -0.018942000874356536
# 0.4618412399278028
# Line: y=-0.018942000874356536x + 0.19783284492821585

# %%
m_true = 3
c_true = 2
err = np.random.rand(len(X2))
X2 = np.arange(0,1.01,0.01)
Y2 = (X2 * m_true) + c_true + err
m_calc, c_calc = leastSq(X2,Y2)
YPred = (X2 * m_calc) + c_calc
print(f"Line is: y = {m_true}x + {c_true}")
print(f"Predicted line is: y = {m_calc}x + {c_calc}")

r = (Y2 - YPred)
maxr = np.max(r)
minr = np.min(r)
print("Residuals: ")
print(r)
print(f"Max Residual: {maxr}")
print(f"Min Residual: {minr}")
# Out:
# Line is: y = 3x + 2
# Predicted line is: y = 3.159676648686114x + 2.408252883390732
# Residuals:
# [ 0.25084649  0.00577917 -0.34711817 -0.31902364  0.56391095  0.52040953
#  -0.41676887 -0.15771008  0.35447481 -0.32005184  0.11999495  0.34684117
#   0.4179913   0.09701264 -0.18193761 -0.17945293 -0.06330578  0.36262689
#   0.04459489 -0.20998001 -0.25583969 -0.02771064 -0.04557743  0.49908138
#  -0.33789379 -0.25472886 -0.20341653 -0.32117518  0.46716158  0.11600584
#  -0.31308468 -0.09806821 -0.43786798 -0.26182446  0.24982828 -0.04058901
#   0.21836437 -0.40414707  0.2050756   0.04237729  0.07943415 -0.17616389
#   0.4395848  -0.4690356   0.2414785   0.33915883 -0.023062   -0.40339068
#  -0.34907803  0.19395287 -0.04893631  0.04639178  0.43693352 -0.23615349
#  -0.47859297  0.36667406  0.41694137  0.29036516 -0.17160362 -0.01641728
#   0.09362628  0.30284022 -0.33949363  0.48868194 -0.00393007 -0.08339708
#  -0.4471905   0.19637845 -0.40011424  0.39177391  0.17230961 -0.48594103
#   0.25308667 -0.28549556  0.28472093 -0.30089402 -0.35861957  0.19248666
#  -0.03386587 -0.37119606  0.36177878 -0.3937886   0.03822382 -0.22246079
#   0.32783612 -0.03725487 -0.35961468  0.34624932  0.25099368 -0.05001235
#  -0.25949324 -0.30284334 -0.1847062  -0.20014016  0.19954506  0.10571339
#   0.39386258  0.22393017 -0.30507085  0.28933715  0.34856214]
# Max Residual: 0.5639109492147276
# Min Residual: -0.48594103447046155

# %%
import matplotlib.pyplot as plt

plt.scatter(X2, Y2, label="Random data")
plt.plot(X2, YPred, color="red", label="Best fit line")

plt.legend()
plt.show()

# %%
A = np.vstack([X2, np.ones(len(X2))]).T
m_np, c_np = np.linalg.lstsq(A, Y2, rcond=None)[0]
print("My Least Squares:")
print(f"m = {m_calc}, c = {c_calc}")

print("NumPy Least Squares:")
print(f"m = {m_np}, c = {c_np}")
# Out:
# My Least Squares:
# m = 3.159676648686114, c = 2.408252883390732
# NumPy Least Squares:
# m = 3.1596766486861108, c = 2.4082528833907335
